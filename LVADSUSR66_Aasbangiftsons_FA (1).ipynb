# %%
#Q1
import pandas as pd
df = pd.read_csv('/content/Walmart_Dataset Python_Final_Assessment.csv')
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3203 entries, 0 to 3202
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      3203 non-null   object
#  1   Order Date    3203 non-null   object
#  2   Ship Date     3203 non-null   object
#  3   EmailID       3203 non-null   object
#  4   Geography     3203 non-null   object
#  5   Category      3203 non-null   object
#  6   Product Name  3203 non-null   object
#  7   Sales         3203 non-null   float64
#  8   Quantity      3203 non-null   float64
#  9   Profit        3203 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 250.4+ KB
# None
#               Sales     Quantity       Profit
# count   3203.000000  3203.000000  3203.000000
# mean     226.493266     3.828910    33.849138
# std      524.876911     2.260947   174.109155
# min        0.990000     1.000000 -3399.980000
# 25%       19.440000     2.000000     3.850000
# 50%       60.840000     3.000000    11.170000
# 75%      215.810000     5.000000    33.000000
# max    13999.960000    14.000000  6719.980000

# %%
#Q2
print(df.isnull().sum())
#no missing values
df.drop_duplicates(inplace=True)
# Out:
# Order ID        0
# Order Date      0
# Ship Date       0
# EmailID         0
# Geography       0
# Category        0
# Product Name    0
# Sales           0
# Quantity        0
# Profit          0
# dtype: int64

# %%
#Q3
print("Mean: Sales \n", df['Sales'].mean())
print("Median: Sales \n", df['Sales'].median())
print("Mode: Sales \n", df['Sales'].mode())
print("Range: Sales \n", df['Sales'].max() - df['Sales'].min())
print("Variance: Sales \n", df['Sales'].var())
print("Standard Deviation: Sales \n", df['Sales'].std())
print("Mean: Quantity \n", df['Quantity'].mean())
print("Median: Quantity \n", df['Quantity'].median())
print("Mode: Quantity \n", df['Quantity'].mode())
print("Range: Quantity \n", df['Quantity'].max() - df['Quantity'].min())
print("Variance: Quantity \n", df['Quantity'].var())
print("Standard Deviation: Quantity \n", df['Quantity'].std())
print("Mean: Profit \n", df['Profit'].mean())
print("Median: Profit \n", df['Profit'].median())
print("Mode: Profit \n", df['Profit'].mode())
print("Range: Profit \n", df['Profit'].max() - df['Profit'].min())
print("Variance: Profit \n", df['Profit'].var())
print("Standard Profit: Profit \n", df['Profit'].std())
# Out:
# Mean: Sales
#  226.4932656884171
# Median: Sales
#  60.84
# Mode: Sales
#  0    12.96
# Name: Sales, dtype: float64
# Range: Sales
#  13998.97
# Variance: Sales
#  275495.7714186886
# Standard Deviation: Sales
#  524.8769107311624
# Mean: Quantity
#  3.8289103965032782
# Median: Quantity
#  3.0
# Mode: Quantity
#  0    3.0
# Name: Quantity, dtype: float64
# Range: Quantity
#  13.0
# Variance: Quantity
#  5.111880979788818
# Standard Deviation: Quantity
#  2.2609469210463162
# Mean: Profit
#  33.849138307836405
# Median: Profit
#  11.17
# Mode: Profit
#  0    6.22
# Name: Profit, dtype: float64
# Range: Profit
#  10119.96
# Variance: Profit
#  30313.997689700733
# Standard Profit: Profit
#  174.109154525834

# %%
#Q4
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df['Order Year'] = pd.to_datetime(df['Order Date']).dt.year


salesData = df.groupby('Order Year')['Sales'].sum()
salesData.plot(label='Sales')
profitData = df.groupby('Order Year')['Profit'].sum()
profitData.plot(label='Profit')
plt.grid(True)
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Sales', data=df)
plt.title('Sales by Category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Quantity', y='Profit', data=df)
plt.title('Profit vs Quantity')
plt.xlabel('Quantity')
plt.ylabel('Profit')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='Profit', data=df)
plt.title('Profit Distribution')
plt.xlabel('Profit')
plt.tight_layout()
plt.show()

# %%
#Q5
df.corr()
# Out:
# <ipython-input-23-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              Sales  Quantity    Profit
# Sales     1.000000  0.214665  0.647477
# Quantity  0.214665  1.000000  0.093240
# Profit    0.647477  0.093240  1.000000

# %%
#6
numeric_cols = ['Sales', 'Quantity', 'Profit']
df_zscores = df[numeric_cols].apply(lambda x: np.abs((x - x.mean()) / x.std()))

outliers = df_zscores > 3

outliers_data = df[outliers.any(axis=1)]

print("Outliers:")
print(outliers_data)

plt.figure(figsize=(10, 6))
sns.boxplot(data=df[numeric_cols])
plt.title('Boxplot of Sales, Quantity, and Profit')
plt.xlabel('Features')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Outliers:
#             Order ID Order Date  Ship Date                   EmailID  \
# 44    CA-2013-145583 2013-10-14 2013-10-20   LenaCreighton@gmail.com
# 72    CA-2013-145625 2013-12-09 2013-09-18  KellyCollister@gmail.com
# 111   US-2011-135972 2011-09-21 2011-09-23       JackGarza@gmail.com
# 120   CA-2014-117457 2014-09-12 2014-12-13    KeithHerrera@gmail.com
# 134   CA-2013-109869 2013-04-23 2013-04-30    TanjaNorvell@gmail.com
# ...              ...        ...        ...                       ...
# 3091  CA-2013-160717 2013-07-06 2013-12-06    MariaEtezadi@gmail.com
# 3161  CA-2012-164301 2012-03-26 2012-03-30    EllisBallard@gmail.com
# 3177  CA-2013-129630 2013-05-09 2013-05-09    IoniaMcGrath@gmail.com
# 3182  CA-2014-164028 2014-11-25 2014-01-12         JohnLee@gmail.com
# 3197  US-2013-103674 2013-07-12 2013-11-12       AnnePryor@gmail.com
#
#                                    Geography     Category  \
# 44        United States,Roseville,California  Furnishings
# 72        United States,San Diego,California  Accessories
# 111      United States,Des Moines,Washington      Copiers
# 120   United States,San Francisco,California    Bookcases
# 134            United States,Phoenix,Arizona       Tables
# ...                                      ...          ...
# 3091  United States,Santa Barbara,California       Phones
# 3161        United States,Seattle,Washington       Tables
# 3177  United States,San Francisco,California      Copiers
# 3182  United States,San Francisco,California  Accessories
# 3197    United States,Los Angeles,California      Binders
#
#                                            Product Name    Sales  Quantity  \
# 44                         Longer-Life Soft White Bulbs    43.12      14.0
# 72                  LogitechÂ P710e Mobile Speakerphone  3347.37      13.0
# 111                       Canon PC1080F Personal Copier  1799.97       3.0
# 120          O'Sullivan 4-Shelf Bookcase in Odessa Pine  1336.83      13.0
# 134   Bush Advantage Collection Racetrack Conference...  1272.63       6.0
# ...                                                 ...      ...       ...
# 3091                            Samsung Galaxy Mega 6.3  3023.93       9.0
# 3161  Bush Advantage Collection Racetrack Conference...  3393.68       8.0
# 3177                 Canon PC1060 Personal Laser Copier  2799.96       5.0
# 3182  Memorex Mini Travel Drive 16 GB USB 2.0 Flash ...   223.58      14.0
# 3197                  Ibico Recycled Linen-Style Covers   437.47      14.0
#
#       Profit
# 44     20.70
# 72    636.00
# 111   701.99
# 120    31.45
# 134  -814.48
# ...      ...
# 3091  226.79
# 3161  610.86
# 3177  944.99
# 3182   87.20
# 3197  153.12
#
# [102 rows x 10 columns]

# %%
#Q7 - Trend Analysis
# i)
df['Order Month'] = pd.to_datetime(df['Order Date']).dt.month
salesData = df.groupby('Order Year')['Sales'].sum()
salesData.plot(label='Sales')
profitData = df.groupby('Order Year')['Profit'].sum()
profitData.plot(label='Profit')
plt.grid(True)
plt.legend()
plt.show()

salesData = df.groupby('Order Month')['Sales'].sum()
salesData.plot(label='Sales')
profitData = df.groupby('Order Month')['Profit'].sum()
profitData.plot(label='Profit')
plt.grid(True)
plt.legend()
plt.show()

# ii)
total_sales = df.groupby(['Order Year', 'Category'])['Sales'].sum().reset_index()
total_sales['Growth'] = total_sales.groupby('Category')['Sales'].pct_change() * 100
most_growth_category = total_sales.groupby('Category')['Growth'].mean().idxmax()
print("Category with the Most Growth in Sales:", most_growth_category)
# Out:
# Category with the Most Growth in Sales: Supplies

# %% [markdown]
# ### There is a spike in both sales and profit in the month of march alone and a significant dip in sales in the month of june and october. However both sales and profit shows a linear increase in value throughout the years

# %%
#Q7- Customer Analysis
#i)
customer_summary = df.groupby('EmailID').agg({'Order ID': 'nunique', 'Sales': 'sum'}).reset_index()
customer_summary.columns = ['EmailID', 'Quantity', 'TotalSales']

top_customers_by_orders = customer_summary.nlargest(5, 'Quantity')
top_customers_by_sales = customer_summary.nlargest(5, 'TotalSales')

print("Top 5 Customers by Orders Placed:")
print(top_customers_by_orders.set_index('EmailID'))
print("\nTop 5 Customers by Total Sales:")
print(top_customers_by_sales.set_index('EmailID'))
# Out:
# Top 5 Customers by Orders Placed:
#                          Quantity  TotalSales
# EmailID
# ArianneIrving@gmail.com         7     3800.52
# BillDonatelli@gmail.com         7     2231.48
# SallyHughsby@gmail.com          7     2238.03
# SanjitEngle@gmail.com           7     2269.11
# ArthurPrichep@gmail.com         6     2370.64
#
# Top 5 Customers by Total Sales:
#                          Quantity  TotalSales
# EmailID
# RaymondBuch@gmail.com           2    14345.28
# KenLonsdale@gmail.com           5     8472.39
# EdwardHooks@gmail.com           5     7447.77
# JaneWaco@gmail.com              3     7391.53
# KarenFerguson@gmail.com         4     7182.76

# %% [markdown]
# Insights - Customers who tend to spend more , spend them on less number of products and customers who tend to buy more tend to spend less on each product.

# %%
#Q7- Customer Analysis
#ii)
df['OrderDate'] = pd.to_datetime(df['Order Date'])
df.sort_values(by=['EmailID', 'Order Date'], inplace=True)
df['TimeBetweenOrders'] = df.groupby('EmailID')['Order Date'].diff()
average_time_between_orders = df.groupby('EmailID')['TimeBetweenOrders'].mean()

print("Average Time Between Orders for Each Customer:")
print(average_time_between_orders)
print(average_time_between_orders.mean())
# Out:
# Average Time Between Orders for Each Customer:
# EmailID
# AaronBergman@gmail.com                    0 days 00:00:00
# AaronHawkins@gmail.com                  148 days 12:00:00
# AaronSmayling@gmail.com                 112 days 12:00:00
# AdamBellavance@gmail.com                171 days 12:00:00
# AdamHart@gmail.com                      220 days 12:00:00
#                                           ...
# XylonaPreis@gmail.com         110 days 17:27:16.363636364
# YanaSorensen@gmail.com                  143 days 16:00:00
# YosephCarroll@gmail.com                 236 days 00:00:00
# ZuschussCarroll@gmail.com                66 days 19:12:00
# ZuschussDonatelli@gmail.com             399 days 00:00:00
# Name: TimeBetweenOrders, Length: 686, dtype: timedelta64[ns]
# 157 days 15:03:56.909539736

# %% [markdown]
# #Comprehensive Analysis

# %%
#average Time between order and delivery
df['TimeBetweenOrderAndDelivery'] = df['Ship Date'] - df['Order Date']
average_time_between_order_and_delivery = df.groupby('Category')['TimeBetweenOrderAndDelivery'].mean()
print(average_time_between_order_and_delivery)

df['TimeBetweenOrderAndDelivery'] = df['Ship Date'] - df['Order Date']
average_time_between_order_and_delivery = df.groupby('EmailID')['TimeBetweenOrderAndDelivery'].mean()
print(average_time_between_order_and_delivery.mean())
# Out:
# Category
# Accessories             -5 days +12:00:00
# Appliances    -7 days +11:28:14.117647059
# Art                6 days 01:09:07.200000
# Binders        11 days 07:50:49.681528662
# Bookcases               -6 days +23:24:00
# Chairs          4 days 10:19:07.826086956
# Copiers                -11 days +00:57:36
# Envelopes       3 days 10:23:17.014925373
# Fasteners                11 days 01:40:00
# Furnishings    11 days 05:22:06.315789473
# Labels        -1 days +17:35:10.344827587
# Machines        3 days 22:46:09.230769230
# Paper                     2 days 16:09:36
# Phones          2 days 19:29:40.505415162
# Storage         7 days 21:23:00.451127819
# Supplies       14 days 02:05:13.043478260
# Tables         31 days 07:39:18.620689655
# Name: TimeBetweenOrderAndDelivery, dtype: timedelta64[ns]
# 8 days 20:48:44.384743576

# %% [markdown]
# #### i) As of now the average time taken for the shipment of an order is 8 days and 20 hours.It stands highest for Tables delivery . Allocation of bigger trucks through optimised organisation of transporters can be introduced to improve the supply chain.

# %%
import plotly.express as px
fig = px.scatter_geo(df, locations="Geography", locationmode="USA-states",
                      hover_name="Product Name", size="Sales", color="Sales",
                      scope="usa", title="Geographical Distribution")
fig.show()
#Places cannot be plotted because of lack of lat long.
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3c99e281-dd14-4928-b23e-5d6e34520919" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c99e281-dd14-4928-b23e-5d6e34520919")) {                    Plotly.newPlot(                        "3c99e281-dd14-4928-b23e-5d6e34520919",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eSales=%{marker.color}\u003cbr\u003eGeography=%{location}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Newell 330","Global Push Button Manager's Chair, Indigo","Carina 42\"Hx23 3\u002f4\"W Media Storage Unit","Iceberg Nesting Folding Chair, 19w x 6d x 43h","EcoTones Memo Sheets","GBC VeloBind Cover Sets","Geemarc AmpliPOWER60","Fellowes Super Stor\u002fDrawer Files","Atlantic Metals Mobile 4-Shelf Bookcases, Custom Colors","Lesro Sheffield Collection Coffee Table, End Table, Center Table, Corner Table","Avery Trapezoid Extra Heavy Duty 4\" Binders","Wirebound Message Books, Four 2 3\u002f4\" x 5\" Forms per Page, 600 Sets per Book","SanDisk Cruzer 64 GB USB Flash Drive","Hon 2090 \u00c2\u201cPillow Soft\u00c2\u201d Series Mid Back Swivel\u002fTilt Chairs","Hon 5100 Series Wood Tables","Logitech G600 MMO Gaming Mouse","Permanent Self-Adhesive File Folder Labels for Typewriters by Universal","OIC Binder Clips","Ampad Phone Message Book, Recycled, 400 Message Capacity, 5 \u00c2\u00be\u00c2\u201d x 11\u00c2\u201d","Premier Electric Letter Opener","Howard Miller 12\" Round Wall Clock","Belkin 7-Outlet SurgeMaster Home Series","Bevis Boat-Shaped Conference Table","Aastra 6757i CT Wireless VoIP phone","Sony Micro Vault Click 16 GB USB 2.0 Flash Drive","Plastic Binding Combs","Polycom VoiceStation 500 Conference\u00c2\u00a0phone","Akro Stacking Bins","Office Star - Ergonomically Designed Knee Chair","Sony Micro Vault Click 8 GB USB 2.0 Flash Drive","Newell 312","Vinyl Sectional Post Binders","Avery White Multi-Purpose Labels","Black Print Carbonless 8 1\u002f2\" x 8 1\u002f4\" Rapid Memo Book","Macally Suction Cup Mount","Iceberg OfficeWorks 42\" Round Tables","Xerox 1891","Xerox 1942","Eldon Image Series Desk Accessories, Burgundy","Imation Bio 8GB USB\u00c2\u00a0Flash Drive Imation\u00c2\u00a0Corp","Xerox 1977","Staples","GBC Velobind Prepunched Cover Sets, Regency Series","Tennsco Regal Shelving Units","Belkin Standard 104 key USB Keyboard","Flat Face Poster Frame","GBC Wire Binding Combs","Zipper Ring Binder Pockets","Xerox 1919","Canon Image Class D660 Copier","Great White Multi-Use Recycled Paper (20Lb. and 84 Bright)","Advantus Rolling Storage Box","Tennsco Single-Tier Lockers","Staples","Wilson SignalBoost 841262 DB PRO Amplifier Kit","Microsoft Sculpt Comfort Mouse","Newell 323","Green Canvas Binder for 8-1\u002f2\" x 14\" Sheets","Office Impressions Heavy Duty Welded Shelving & Multimedia Storage Drawers","WD My Passport Ultra 1TB Portable External Hard Drive","Belkin 8-Outlet Premiere SurgeMaster II Surge Protectors","Avery Non-Stick Binders","Acco Pressboard Covers with Storage Hooks, 14 7\u002f8\" x 11\", Light Blue","GBC Pre-Punched Binding Paper, Plastic, White, 8-1\u002f2\" x 11\"","Global Adaptabilites Bookcase, Cherry\u002fStorm Gray Finish","Avery 514","Green Bar Computer Printout Paper","Mini 13-1\u002f2 Capacity Data Binder Rack, Pearl","#10- 4 1\u002f8\" x 9 1\u002f2\" Security-Tint Envelopes","Fellowes Mighty 8 Compact Surge Protector","Crayola Colored Pencils","Advantus SlideClip Paper Clips","Xerox 215","Xerox 1885","Acme Elite Stainless Steel Scissors","Brother DCP1000 Digital 3 in 1 Multifunction Machine","Fellowes Super Stor\u002fDrawer","Tenex \"The Solids\" Textured Chair Mats","Square Ring Data Binders, Rigid 75 Pt. Covers, 11\" x 14-7\u002f8 ...

# %% [markdown]
# #### ii) The geographic distribution of sales is influenced by factors such as demographics (age, income), cultural preferences, economic conditions and local requirements. Insights from these factors can inform targeted marketing by enabling businesses to tailor products, pricing, promotions, and advertising strategies to specific regions, demographics, and consumer behaviors thus improving sales performance and customer engagement.

# %%
customer_order_amounts = df.groupby('EmailID')['Sales'].sum().reset_index()

top_10_percent = int(len(customer_order_amounts) * 0.1)
high_value_customers = customer_order_amounts.nlargest(top_10_percent, 'Sales')
print("High value Customers based on purchase Value:")
print(high_value_customers)

customer_order_amounts = df.groupby('EmailID')['Quantity'].sum().reset_index()

top_10_percent = int(len(customer_order_amounts) * 0.1)
high_value_customers = customer_order_amounts.nlargest(top_10_percent, 'Quantity')
print("High value Customers based on purchase Quantity:")
print(high_value_customers)

df.sort_values(by=['EmailID', 'Order Date'], inplace=True)
df['TimeBetweenOrders'] = df.groupby('EmailID')['Order Date'].diff()
average_time_between_orders = df.groupby('EmailID')['TimeBetweenOrders'].mean()
print("High value Customers based on purchase Frequency:")
print(average_time_between_orders.nsmallest(top_10_percent))

for index, customer in high_value_customers.iterrows():
  pass
  #We can write a function to send promotional offers to these value customers
# Out:
# High value Customers based on purchase Value:
#                         EmailID     Sales
# 539       RaymondBuch@gmail.com  14345.28
# 384       KenLonsdale@gmail.com   8472.39
# 214       EdwardHooks@gmail.com   7447.77
# 295          JaneWaco@gmail.com   7391.53
# 362     KarenFerguson@gmail.com   7182.76
# ..                          ...       ...
# 684   ZuschussCarroll@gmail.com   2641.09
# 618  StevenCartwright@gmail.com   2636.82
# 601     SharelleRoach@gmail.com   2613.31
# 579     SandraGlassco@gmail.com   2567.15
# 314    JeremyLonsdale@gmail.com   2563.31
#
# [68 rows x 2 columns]
# High value Customers based on purchase Quantity:
#                         EmailID  Quantity
# 680      WilliamBrown@gmail.com      93.0
# 549        RickWilson@gmail.com      79.0
# 51      ArthurPrichep@gmail.com      76.0
# 618  StevenCartwright@gmail.com      74.0
# 264       GregGuthrie@gmail.com      72.0
# ..                          ...       ...
# 682      YanaSorensen@gmail.com      38.0
# 483       NaresjPatel@gmail.com      37.0
# 637      TanjaNorvell@gmail.com      37.0
# 96     BrosinaHoffman@gmail.com      36.0
# 327         JoeElijah@gmail.com      36.0
#
# [68 rows x 2 columns]
# High value Customers based on purchase Frequency:
# EmailID
# AaronBergman@gmail.com      0 days
# AllenRosenblatt@gmail.com   0 days
# AlyssaCrouse@gmail.com      0 days
# AnnChong@gmail.com          0 days
# AnnePryor@gmail.com         0 days
#                              ...
# MaribethDona@gmail.com      0 days
# MarkCousins@gmail.com       0 days
# MattAbelman@gmail.com       0 days
# MattCollister@gmail.com     0 days
# MatthewClasen@gmail.com     0 days
# Name: TimeBetweenOrders, Length: 68, dtype: timedelta64[ns]

# %% [markdown]
# ### iii) High value customers can be identified by their purchasing quantity, purchase frequency and pruchase amount . These customers can be given additional promotions and offers to enhance customer loyalty and they are more likely to recommend wallmart to other potential customers
